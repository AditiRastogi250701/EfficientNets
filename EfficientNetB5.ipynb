# %% [markdown]
# <a href="https://colab.research.google.com/github/AditiRastogi250701/EfficientNets/blob/main/EfficientNetB5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## EfficientNetB5

# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import tensorflow as tf
import PIL.Image as Image
from tensorflow import keras
from tensorflow.keras.applications.imagenet_utils import decode_predictions

# %%
model=tf.keras.applications.efficientnet.EfficientNetB5(
    include_top=True, 
    weights='imagenet', 
    input_tensor=None, 
    input_shape=None, 
    pooling=None, 
    classes=1000, 
    classifier_activation='softmax')
# Out:
# ...
# 123478016/123465288 [==============================] - 1s 0us/step

# %%
img=Image.open(r'/content/B5-SAMPLE.jpg')
image=Image.open(r'/content/B5-SAMPLE.jpg')

# %%
img=cv2.resize(np.float32(img),(456,456))

# %%
img.shape
# Out:
# (456, 456, 3)

# %%
img
# Out:
# array([[[ 84.41667 ,  96.708336,  72.41667 ],
#         [ 79.6875  ,  93.6875  ,  67.6875  ],
#         [ 78.      ,  93.45833 ,  66.729164],
#         ...,
#         [107.27081 ,  98.27081 ,  89.81244 ],
#         [108.      , 100.125   ,  92.5625  ],
#         [117.39606 , 110.39606 , 102.39606 ]],
#
#        [[ 83.77605 ,  97.34896 ,  72.52605 ],
#         [ 80.015625,  94.015625,  68.765625],
#         [ 78.75    ,  94.20833 ,  67.68229 ],
#         ...,
#         [107.47392 ,  98.47392 ,  89.60933 ],
#         [109.171875, 101.296875,  93.078125],
#         [117.61478 , 112.5367  , 103.89606 ]],
#
#        [[ 83.06424 ,  97.06424 ,  73.2309  ],
#         [ 79.8698  ,  94.3802  ,  69.78125 ],
#         [ 79.267365,  95.04167 ,  68.85069 ],
#         ...,
#         [108.70829 , 100.4496  ,  90.4409  ],
#         [110.40105 , 104.020836,  94.34375 ],
#         [119.26757 , 115.0853  , 104.979385]],
#
#        ...,
#
#        [[234.95985 , 230.5432  , 203.43555 ],
# ...

# %%
img=img[np.newaxis,...]

# %%
img.shape
# Out:
# (1, 456, 456, 3)

# %%
sampleprediction=model.predict(img)

# %%
sampleprediction
# Out:
# array([[1.27845778e-04, 1.05950479e-04, 1.09462671e-04, 1.02592247e-04,
#         7.26594299e-05, 1.76908521e-04, 1.03124403e-04, 8.13656225e-05,
#         7.05863131e-05, 1.49347601e-04, 1.16297044e-04, 2.78737454e-04,
#         1.50895503e-04, 1.72801389e-04, 1.25827952e-04, 1.31341178e-04,
#         2.52159312e-04, 7.26841681e-05, 1.31759327e-04, 1.52998080e-04,
#         2.50681100e-04, 1.35279013e-04, 2.06919169e-04, 7.35452923e-05,
#         1.36720613e-04, 1.43984391e-04, 1.30537010e-04, 8.22719885e-05,
#         1.08089116e-04, 1.54591791e-04, 1.05824554e-04, 1.88857695e-04,
#         1.15212679e-04, 7.20053504e-05, 8.50995057e-05, 1.33892579e-04,
#         7.50769977e-05, 1.90092222e-04, 2.88113835e-04, 1.21370111e-04,
#         1.97154252e-04, 1.57334594e-04, 8.33227969e-05, 2.29470417e-04,
#         1.49553554e-04, 7.91194034e-04, 1.74482018e-04, 1.89528349e-04,
#         1.19166732e-04, 8.21139620e-05, 8.74683974e-05, 1.05754734e-04,
# ...

# %%
sampleans=np.argmax(sampleprediction)

# %%
sampleans
# Out:
# 221

# %%
decode_predictions(sampleprediction,top=3)
# Out:
# ...
# 49152/35363 [=========================================] - 0s 0us/step
# [[('n02102973', 'Irish_water_spaniel', 0.80623794),
#   ('n02099429', 'curly-coated_retriever', 0.020423718),
#   ('n02102480', 'Sussex_spaniel', 0.012169574)]]

# %%
print("Accuracy of prediciton",round(decode_predictions(sampleprediction,top=1)[0][0][2]*100,2),"%")
# Out:
# Accuracy of prediciton 80.62 %

# %%
#Actual Image
plt.axis('off')
plt.imshow(image)

# %% [markdown]
# ## Comparison between EfficientNetB0 and EfficientNetB5

# %%
img1=Image.open(r'/content/B0-SAMPLE.jpg')

# %%
img1=cv2.resize(np.float32(img1),(456,456))

# %%
img1.shape
# Out:
# (456, 456, 3)

# %%
img1=img1[np.newaxis,...]

# %%
img1.shape
# Out:
# (1, 456, 456, 3)

# %%
sampleprediction1=model.predict(img1)

# %%
sampleans1=np.argmax(sampleprediction1)

# %%
sampleans1
# Out:
# 1

# %%
decode_predictions(sampleprediction1,top=3)
# Out:
# [[('n01443537', 'goldfish', 0.8680327),
#   ('n01440764', 'tench', 0.0022136678),
#   ('n02606052', 'rock_beauty', 0.0011440167)]]

# %%
print("Accuracy of prediction: ",round(decode_predictions(sampleprediction1,top=1)[0][0][2]*100,2),"%")
# Out:
# Accuracy of prediction:  86.8 %

# %% [markdown]
# ![image.png](data:image/png;base64,...)
