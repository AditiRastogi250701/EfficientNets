# %% [markdown]
# <a href="https://colab.research.google.com/github/AditiRastogi250701/EfficientNets/blob/main/EfficientNetB6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## EfficientNetB5

# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import tensorflow as tf
import PIL.Image as Image
from tensorflow import keras
from tensorflow.keras.applications.imagenet_utils import decode_predictions

# %%
model=tf.keras.applications.efficientnet.EfficientNetB6(
    include_top=True, 
    weights='imagenet', 
    input_tensor=None, 
    input_shape=None, 
    pooling=None, 
    classes=1000, 
    classifier_activation='softmax')

# %%
img=Image.open(r'/content/B6-SAMPLE.jpg')
image=Image.open(r'/content/B6-SAMPLE.jpg')

# %%
img=cv2.resize(np.float32(img),(528,528))

# %%
img.shape
# Out:
# (528, 528, 3)

# %%
img
# Out:
# array([[[ 81.       , 126.       , 191.       ],
#         [ 81.       , 126.       , 191.       ],
#         [ 81.       , 126.       , 191.       ],
#         ...,
#         [ 40.010406 , 106.01041  , 180.0104   ],
#         [ 39.40625  , 105.40625  , 179.40625  ],
#         [ 39.       , 105.       , 179.       ]],
#
#        [[ 81.       , 126.       , 191.       ],
#         [ 81.       , 126.       , 191.       ],
#         [ 81.       , 126.       , 191.       ],
#         ...,
#         [ 40.010406 , 106.01041  , 180.0104   ],
#         [ 39.40625  , 105.40625  , 179.40625  ],
#         [ 39.       , 105.       , 179.       ]],
#
#        [[ 81.24811  , 126.24811  , 191.24811  ],
#         [ 81.24811  , 126.24811  , 191.24811  ],
#         [ 81.24811  , 126.24811  , 191.24811  ],
#         ...,
#         [ 40.25593  , 106.25593  , 180.25594  ],
#         [ 39.654358 , 105.65436  , 179.65436  ],
#         [ 39.248108 , 105.2481   , 179.24811  ]],
#
#        ...,
#
# ...

# %%
img=img[np.newaxis,...]

# %%
img.shape
# Out:
# (1, 528, 528, 3)

# %%
sampleprediction=model.predict(img)

# %%
sampleprediction
# Out:
# array([[2.42975235e-04, 1.49825879e-04, 1.21963574e-04, 4.30862798e-04,
#         1.91079089e-04, 2.54151848e-04, 1.86159261e-04, 8.48797499e-05,
#         9.92128116e-05, 1.81711323e-04, 3.37070000e-04, 3.57193727e-04,
#         1.82499076e-04, 1.24056605e-04, 2.31340702e-04, 1.01020465e-04,
#         1.46741600e-04, 1.37626106e-04, 1.39367155e-04, 1.94860258e-04,
#         2.48499884e-04, 1.35839276e-04, 8.73340032e-05, 1.86475896e-04,
#         1.12329071e-04, 2.19692563e-04, 2.23860407e-04, 1.18741402e-04,
#         2.24333678e-04, 2.33237311e-04, 1.25553895e-04, 2.27102340e-04,
#         3.87303648e-04, 2.07371690e-04, 1.46976759e-04, 1.26964122e-04,
#         1.52342560e-04, 7.15609713e-05, 3.76835407e-04, 9.44100466e-05,
#         1.28426924e-04, 2.32606792e-04, 2.84062495e-04, 1.09522582e-04,
#         1.28975691e-04, 1.29846143e-04, 7.69345206e-05, 1.87056197e-04,
#         8.19597335e-05, 1.86974343e-04, 9.72580528e-05, 6.64916224e-05,
# ...

# %%
sampleans=np.argmax(sampleprediction)

# %%
sampleans
# Out:
# 698

# %%
decode_predictions(sampleprediction,top=3)
# Out:
# [[('n03877845', 'palace', 0.6605269),
#   ('n03781244', 'monastery', 0.09249972),
#   ('n02980441', 'castle', 0.020770133)]]

# %%
print("Accuracy of prediciton",round(decode_predictions(sampleprediction,top=1)[0][0][2]*100,2),"%")
# Out:
# Accuracy of prediciton 66.05 %

# %%
#Actual Image
plt.axis('off')
plt.imshow(image)

# %% [markdown]
# ## Comparison between EfficientNetB0 and EfficientNetB6

# %%
img1=Image.open(r'/content/B0-SAMPLE.jpg')

# %%
img1=cv2.resize(np.float32(img1),(528,528))

# %%
img1.shape
# Out:
# (528, 528, 3)

# %%
img1=img1[np.newaxis,...]

# %%
img1.shape
# Out:
# (1, 528, 528, 3)

# %%
sampleprediction1=model.predict(img1)

# %%
sampleans1=np.argmax(sampleprediction1)

# %%
sampleans1
# Out:
# 1

# %%
decode_predictions(sampleprediction1,top=3)
# Out:
# [[('n01443537', 'goldfish', 0.76341635),
#   ('n01440764', 'tench', 0.0031297572),
#   ('n02606052', 'rock_beauty', 0.0021359064)]]

# %%
print("Accuracy of prediction: ",round(decode_predictions(sampleprediction1,top=1)[0][0][2]*100,2),"%")
# Out:
# Accuracy of prediction:  76.34 %

# %% [markdown]
# ![image.png](data:image/png;base64,...)
