# %% [markdown]
# <a href="https://colab.research.google.com/github/AditiRastogi250701/EfficientNets/blob/main/EfficientNetB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## EfficientNetB1

# %%
import sys
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import tensorflow as tf
import PIL.Image as Image
from tensorflow import keras
from tensorflow.keras.applications.imagenet_utils import decode_predictions

# %%
model=tf.keras.applications.efficientnet.EfficientNetB1(
    include_top=True, 
    weights='imagenet', 
    input_tensor=None, 
    input_shape=None, 
    pooling=None, 
    classes=1000, 
    classifier_activation='softmax')

# %%
img=Image.open(r'/content/B1-SAMPLE.jpg')
image=Image.open(r'/content/B1-SAMPLE.jpg')

# %%
img=cv2.resize(np.float32(img),(240,240))

# %%
img.shape
# Out:
# (240, 240, 3)

# %%
img
# Out:
# array([[[ 53.537086,  56.537086,  38.28875 ],
#         [ 59.059166,  61.859165,  45.459167],
#         [ 61.302086,  65.302086,  51.24167 ],
#         ...,
#         [ 30.422916,  30.422916,  28.422918],
#         [ 27.01087 ,  27.01087 ,  25.01087 ],
#         [ 22.943745,  22.943745,  20.943745]],
#
#        [[ 67.32    ,  70.32    ,  51.32    ],
#         [ 67.17875 ,  69.97875 ,  53.57875 ],
#         [ 66.725   ,  70.362495,  55.543747],
#         ...,
#         [ 36.81875 ,  36.81875 ,  34.81875 ],
#         [ 33.037525,  33.037525,  31.037525],
#         [ 31.254997,  31.254997,  29.254995]],
#
#        [[ 81.7875  ,  84.7875  ,  65.7875  ],
#         [ 74.19792 ,  77.058334,  60.477085],
#         [ 72.11458 ,  74.114586,  60.114586],
#         ...,
#         [ 35.09375 ,  35.395836,  32.489586],
#         [ 29.950027,  30.252111,  27.345863],
#         [ 28.727085,  28.727085,  26.727085]],
#
#        ...,
#
#        [[163.88715 , 164.88715 , 147.49133 ],
# ...

# %%
img=img[np.newaxis,...]

# %%
img.shape
# Out:
# (1, 240, 240, 3)

# %%
sampleprediction=model.predict(img)

# %%
sampleprediction
# Out:
# array([[3.06305272e-04, 1.03095808e-04, 3.89565321e-05, 3.66287495e-05,
#         7.15875576e-05, 1.10910602e-04, 6.68655557e-05, 1.21238714e-04,
#         1.66257261e-04, 3.96304349e-05, 1.01347148e-04, 2.10676575e-04,
#         1.42332050e-04, 1.03946419e-04, 2.01407413e-04, 1.13711008e-04,
#         1.44824618e-04, 6.99756565e-05, 1.93781598e-04, 9.63092607e-05,
#         2.79994740e-04, 1.23626858e-04, 1.36446310e-04, 2.13241292e-04,
#         1.42306002e-04, 9.72776688e-05, 2.09964521e-04, 8.94716432e-05,
#         1.59135947e-04, 3.08402494e-04, 1.24876038e-04, 2.93053454e-05,
#         5.51317098e-05, 2.50336423e-04, 2.75621482e-04, 4.10582026e-04,
#         1.80821997e-04, 1.40918215e-04, 2.76830135e-04, 2.39202427e-03,
#         9.59079916e-05, 3.98225762e-04, 1.46613253e-04, 8.83038330e-04,
#         5.25411917e-04, 3.69598367e-03, 3.11908108e-04, 1.54924172e-04,
#         8.70484293e-01, 5.23770461e-04, 7.72564090e-04, 2.04472733e-03,
# ...

# %%
sampleans=np.argmax(sampleprediction)

# %%
sampleans
# Out:
# 48

# %%
labels=pd.read_csv(r'/content/Label.txt',header=None)

# %%
labels
# Out:
#                      0
# 0                tench
# 1             goldfish
# 2    great white shark
# 3          tiger shark
# 4           hammerhead
# ..                 ...
# 995          earthstar
# 996   hen-of-the-woods
# 997             bolete
# 998                ear
# 999      toilet tissue
#
# [1000 rows x 1 columns]

# %%
labels.iloc[sampleans]
# Out:
# 0    Komodo dragon
# Name: 48, dtype: object

# %%
decode_predictions(sampleprediction,top=3)
# Out:
# [[('n01695060', 'Komodo_dragon', 0.8704843),
#   ('n01692333', 'Gila_monster', 0.0036959837),
#   ('n01677366', 'common_iguana', 0.0023920243)]]

# %%
#checking the original image
plt.axis('off')
plt.imshow(image)

# %%
print("Accuracy of prediction: ",round(decode_predictions(sampleprediction,top=1)[0][0][2]*100,2),"%")
# Out:
# Accuracy of prediction:  87.05 %

# %% [markdown]
# ## Comparison between EfficientNetB0 and EfficientNetB1

# %%
img1=Image.open(r'/content/B0-SAMPLE.jpg')

# %%
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=281x180 at 0x7F9304D4BC90>

# %%
img1=cv2.resize(np.float32(img1),(240,240))

# %%
img1
# Out:
# array([[[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        ...,
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
# ...

# %%
img1=img1[np.newaxis,...]

# %%
img1.shape
# Out:
# (1, 240, 240, 3)

# %%
sampleprediction1=model.predict(img1)

# %%
sampleans1=np.argmax(sampleprediction1)

# %%
sampleans1
# Out:
# 1

# %%
print("Accuracy of prediction: ",round(decode_predictions(sampleprediction1,top=1)[0][0][2]*100,2),"%")
# Out:
# Accuracy of prediction:  91.13 %

# %% [markdown]
# #### EfficientNetB1 gives an accuracy of 91.13% whereas EfficientNetB0 gives an accuracy of 95.6% for the same prediciton
